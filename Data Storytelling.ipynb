# %% [markdown]
# # Data Storytelling
# ## Steps and Summary:
# This analysis is done on a sample dataset of accidents in 48states and D.C. in the period **Feb 2016** till **Dec2019**.<br>
#
# 1) load *fillna csv file and check proportion of Severity in dataset.<br>
# Severities '2' and '3' represent most of the dataset at 67% and 29.7% respectively.<br>
# 82% of the accidents were on the Right side of the road and 18% on the left.<br>
#
# 2) Map of distribution of accidents by severity in the US.<br>
# the majority of the accidents are on the East and West coast of the US.<br>
#
# 3) Total number of accidents by Day of the Week:<br>
# Total number of accidents happen on Tuesdays, but the most severe occur on Fridays.<br>
#
# 4) Total accidents graph, by weather condition, Day/Night, Day_of_week, Hour_of_day, city and state.<br>
# There are 97 different weather conditions in the dataset, the top 10 were graphed. Most accidents occur on Clear days, followed by Partly Cloudy and Overcast days.<br>
# Nights seem to be the time when less accidents happen, as do Saturdays and Sundays.<br>
#
# 7am and 8am , are the times of the day with the most accidents recorded, followed by 4pm and 5pm. These represent the morning and evening rush hours.<br>
#
# 5) States and cities with the highest number of Severest accidents.<br>
# California and Texas are the two states with the highest number of accidents, however Florida and Georgia are the states with the severest accidents while California is number 3. Miami and Atlanta are the cities where the severest road accidents happen in the US.
# As far as total number of accidents go, Houston takes the prize, followed by Charlotte and Los Angeles.<br>
#
# 6) Pairplots 1 and 2 show that level4 Severity is not seen at high Visibility, high Wind_Speed nor high Precipitation
#
# 7) Plotting the yearly and monthly counts of road accidents highlights:<br>
# > - There has been an increasing trend in total accidents, and
# >- There is a jump in the total number of accidents around the 3rd Quarter of 2017.<br>
#
# 8) Traffic_Signals are the site for most accidents, followed by Crossings and Junctions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as datetime

import gc

pd.set_option('display.max_columns', 999)

# %matplotlib inline

# %%
# read in dataset
#na = pd.read_csv('dec19_400k_rs1_edt_fillna.csv')
na = pd.read_csv('dec19_400k_rs1_edt_fillna.csv', parse_dates=['Start_Time', 'End_Time', 'Weather_Timestamp'])

# %%
na.describe().transpose()
# Out:
#                                 count          mean            std  \
# Unnamed: 0                   400000.0  1.999995e+05  115470.198175
# Unnamed: 0.1                 400000.0  1.490152e+06  858207.037319
# TMC                          301701.0  2.078415e+02      20.295358
# Severity                     400000.0  2.360142e+00       0.541752
# Start_Lat                    400000.0  3.649319e+01       4.919935
# Start_Lng                    400000.0 -9.541889e+01      17.210788
# End_Lat                       98299.0  3.759917e+01       5.002061
# End_Lng                       98299.0 -9.998674e+01      18.415574
# Distance(mi)                 400000.0  2.875614e-01       1.587642
# Number                       141503.0  5.820273e+03   11736.123756
# Temperature(F)               392443.0  6.236745e+01      18.780979
# Wind_Chill(F)                151072.0  5.132821e+01      25.149195
# Humidity(%)                  392044.0  6.539851e+01      22.577303
# Pressure(in)                 393526.0  2.982998e+01       0.733241
# Visibility(mi)               391156.0  9.155309e+00       2.904976
# Wind_Speed(mph)              341003.0  8.305884e+00       4.874132
# Precipitation(in)            131252.0  1.973227e-02       0.220855
# Hour_of_Day                  400000.0  1.210591e+01       5.096637
# Precipitation_filled         400000.0  6.474750e-03       0.126850
# Wind_Speed_filled_mean       400000.0  8.305884e+00       4.500350
# Wind_Speed_filled_median     400000.0  8.113276e+00       4.524111
# Humidity_filled_mean         400000.0  6.539851e+01      22.351643
# Temperature_filled_mean      400000.0  6.236745e+01      18.602723
# Temperature_filled_median    400000.0  6.240585e+01      18.604781
# Visibility_filled_mean       400000.0  9.155309e+00       2.872682
# Pressure_filled_mean         400000.0  2.982998e+01       0.727283
# Wind_Chill_predicted_filled  400000.0  6.048153e+01      21.379503
#
#                                     min            25%           50%  \
# Unnamed: 0                     0.000000   99999.750000  1.999995e+05
# Unnamed: 0.1                  12.000000  747469.000000  1.491116e+06
# TMC                          200.000000     201.000000  2.010000e+02
# Severity                       1.000000       2.000000  2.000000e+00
# Start_Lat                     24.570442      33.552807  3.584462e+01
# Start_Lng                   -124.497523    -117.291287 -9.028814e+01
# End_Lat                       24.571534      33.959787  3.792923e+01
# End_Lng                     -124.497442    -118.286333 -9.662868e+01
# Distance(mi)                   0.000000       0.000000  0.000000e+00
# Number                         1.000000     845.500000  2.716000e+03
# Temperature(F)               -77.800000      50.000000  6.440000e+01
# Wind_Chill(F)                -52.700000      32.000000  5.400000e+01
# Humidity(%)                    1.000000      49.000000  6.800000e+01
# Pressure(in)                   0.300000      29.820000  2.998000e+01
# Visibility(mi)                 0.000000      10.000000  1.000000e+01
# Wind_Speed(mph)                0.000000       4.600000  7.000000e+00
# Precipitation(in)              0.000000       0.000000  0.000000e+00
# Hour_of_Day                    0.000000       8.000000  1.200000e+01
# Precipitation_filled           0.000000       0.000000  0.000000e+00
# Wind_Speed_filled_mean         0.000000       5.800000  8.100000e+00
# Wind_Speed_filled_median       0.000000       5.800000  7.000000e+00
# Humidity_filled_mean           1.000000      49.000000  6.700000e+01
# Temperature_filled_mean      -77.800000      51.000000  6.400000e+01
# Temperature_filled_median    -77.800000      51.000000  6.440000e+01
# Visibility_filled_mean         0.000000      10.000000  1.000000e+01
# Pressure_filled_mean           0.300000      29.820000  2.997000e+01
# Wind_Chill_predicted_filled -105.272215      47.782983  6.300000e+01
#
#                                       75%           max
# Unnamed: 0                   2.999992e+05  3.999990e+05
# Unnamed: 0.1                 2.234019e+06  2.974329e+06
# TMC                          2.010000e+02  4.060000e+02
# Severity                     3.000000e+00  4.000000e+00
# Start_Lat                    4.036781e+01  4.900058e+01
# Start_Lng                   -8.091863e+01 -6.760688e+01
# End_Lat                      4.138087e+01  4.907500e+01
# End_Lng                     -8.234398e+01 -6.762660e+01
# Distance(mi)                 1.000000e-02  3.336300e+02
# Number                       6.999000e+03  9.610520e+05
# Temperature(F)               7.600000e+01  1.688000e+02
# Wind_Chill(F)                7.300000e+01  1.150000e+02
# Humidity(%)                  8.400000e+01  1.000000e+02
# Pressure(in)                 3.011000e+01  3.115000e+01
# Visibility(mi)               1.000000e+01  1.110000e+02
# Wind_Speed(mph)              1.150000e+01  2.300000e+02
# Precipitation(in)            0.000000e+00  1.018000e+01
# Hour_of_Day                  1.600000e+01  2.300000e+01
# Precipitation_filled         0.000000e+00  1.018000e+01
# Wind_Speed_filled_mean       1.040000e+01  2.300000e+02
# Wind_Speed_filled_median     1.040000e+01  2.300000e+02
# Humidity_filled_mean         8.400000e+01  1.000000e+02
# Temperature_filled_mean      7.590000e+01  1.688000e+02
# Temperature_filled_median    7.590000e+01  1.688000e+02
# Visibility_filled_mean       1.000000e+01  1.110000e+02
# Pressure_filled_mean         3.011000e+01  3.115000e+01
# Wind_Chill_predicted_filled  7.610045e+01  1.803153e+02

# %%
na.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'ID', 'Source', 'TMC', 'Severity',
#        'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng', 'End_Lat',
#        'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street', 'Side',
#        'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'Day_of_Week', 'Hour_of_Day',
#        'Precipitation_wasnull', 'Wind_Chill_wasnull', 'Wind_Speed_wasnull',
#        'Visibility_wasnull', 'Humidity_wasnull', 'Temperature_wasnull',
#        'Pressure_wasnull', 'Precipitation_filled', 'Wind_Speed_filled_mean',
#        'Wind_Speed_filled_median', 'Humidity_filled_mean',
#        'Temperature_filled_mean', 'Temperature_filled_median',
#        'Visibility_filled_mean', 'Pressure_filled_mean', 'Rush_Hour',
#        'Wind_Chill_predicted_filled'],
#       dtype='object')

# %%
na.shape
# Out:
# (400000, 70)

# %%
na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400000 entries, 0 to 399999
# Data columns (total 70 columns):
# Unnamed: 0                     400000 non-null int64
# Unnamed: 0.1                   400000 non-null int64
# Unnamed: 0.1.1                 400000 non-null int64
# ID                             400000 non-null object
# Source                         400000 non-null object
# TMC                            301701 non-null float64
# Severity                       400000 non-null int64
# Start_Time                     400000 non-null datetime64[ns]
# End_Time                       400000 non-null datetime64[ns]
# Start_Lat                      400000 non-null float64
# Start_Lng                      400000 non-null float64
# End_Lat                        98299 non-null float64
# End_Lng                        98299 non-null float64
# Distance(mi)                   400000 non-null float64
# Description                    400000 non-null object
# Number                         141503 non-null float64
# Street                         400000 non-null object
# Side                           400000 non-null object
# City                           399990 non-null object
# County                         400000 non-null object
# State                          400000 non-null object
# Zipcode                        399870 non-null object
# Country                        400000 non-null object
# Timezone                       399552 non-null object
# Airport_Code                   399213 non-null object
# Weather_Timestamp              394983 non-null datetime64[ns]
# Temperature(F)                 392443 non-null float64
# Wind_Chill(F)                  151072 non-null float64
# Humidity(%)                    392044 non-null float64
# Pressure(in)                   393526 non-null float64
# Visibility(mi)                 391156 non-null float64
# Wind_Direction                 393897 non-null object
# Wind_Speed(mph)                341003 non-null float64
# Precipitation(in)              131252 non-null float64
# Weather_Condition              391170 non-null object
# Amenity                        400000 non-null bool
# Bump                           400000 non-null bool
# Crossing                       400000 non-null bool
# Give_Way                       400000 non-null bool
# Junction                       400000 non-null bool
# No_Exit                        400000 non-null bool
# Railway                        400000 non-null bool
# Roundabout                     400000 non-null bool
# Station                        400000 non-null bool
# Stop                           400000 non-null bool
# Traffic_Calming                400000 non-null bool
# Traffic_Signal                 400000 non-null bool
# Turning_Loop                   400000 non-null bool
# Sunrise_Sunset                 399989 non-null object
# Civil_Twilight                 399989 non-null object
# Nautical_Twilight              399989 non-null object
# Astronomical_Twilight          399989 non-null object
# Day_of_Week                    400000 non-null int64
# Hour_of_Day                    400000 non-null int64
# Precipitation_wasnull          400000 non-null bool
# Wind_Chill_wasnull             400000 non-null bool
# Wind_Speed_wasnull             400000 non-null bool
# Visibility_wasnull             400000 non-null bool
# Humidity_wasnull               400000 non-null bool
# Temperature_wasnull            400000 non-null bool
# Pressure_wasnull               400000 non-null bool
# Precipitation_filled           400000 non-null float64
# Wind_Speed_filled_mean         400000 non-null float64
# Wind_Speed_filled_median       400000 non-null float64
# Humidity_filled_mean           400000 non-null float64
# Temperature_filled_mean        400000 non-null float64
# Temperature_filled_median      400000 non-null float64
# Visibility_filled_mean         400000 non-null float64
# Pressure_filled_mean           400000 non-null float64
# Wind_Chill_predicted_filled    400000 non-null float64
# dtypes: bool(20), datetime64[ns](3), float64(23), int64(6), object(18)
# memory usage: 160.2+ MB

# %%
#selecting columns with categorical or numerical data
#na.select_dtypes("object").head()
#na.select_dtypes("number").head()

# %%
na.reset_index(drop=True).head()
# Out:
#    Unnamed: 0  Unnamed: 0.1         ID    Source    TMC  Severity  \
# 0           0        298435   A-298438  MapQuest  201.0         2
# 1           1       2327373  A-2327397      Bing    NaN         3
# 2           2       2333228  A-2333252      Bing    NaN         2
# 3           3        973611   A-973622  MapQuest  201.0         2
# 4           4       2905068  A-2905092      Bing    NaN         2
#
#            Start_Time            End_Time  Start_Lat   Start_Lng   End_Lat  \
# 0 2016-09-01 20:24:12 2016-09-01 20:54:12  30.295200  -97.736923       NaN
# 1 2016-08-29 00:42:10 2016-08-29 06:42:10  29.977700  -90.061000  29.99615
# 2 2016-06-24 13:27:09 2016-06-24 19:27:09  41.846930  -87.948100  41.84693
# 3 2019-05-03 08:18:18 2019-05-03 08:47:59  40.111660  -75.129280       NaN
# 4 2019-04-11 23:11:04 2019-04-12 03:11:04  44.377351 -123.786987  44.37729
#
#       End_Lng  Distance(mi)  \
# 0         NaN         0.000
# 1  -90.045540         1.575
# 2  -87.948100         0.000
# 3         NaN         0.000
# 4 -123.753117         1.673
#
#                                          Description   Number        Street  \
# 0                   Accident on 31st St at Speedway.    101.0     W 31st St
# 1  Between Elysian Fields Ave/Exit 237 and I-610/...      NaN        I-10 E
# 2                        At McDonalds Dr - Accident.      NaN     Spring Rd
# 3         Accident on Highland Ave at Canterbury Rd.      NaN  Highland Ave
# 4                     At Digger Creek Rd - Accident.  23843.0   E Alsea Hwy
#
#   Side         City      County State     Zipcode Country    Timezone  \
# 0    L       Austin      Travis    TX  78705-2909      US  US/Central
# 1    R  New Orleans     Orleans    LA       70116      US  US/Pacific
# 2    R    Oak Brook      DuPage    IL       60523      US  US/Central
# 3    R     Abington  Montgomery    PA       19001      US  US/Eastern
# 4    L        Alsea     Lincoln    OR  97324-9506      US  US/Pacific
#
#   Airport_Code   Weather_Timestamp  Temperature(F)  Wind_Chill(F)  \
# 0         KATT 2016-09-01 20:51:00            84.0            NaN
# 1         KAUD 2016-08-29 00:55:00            77.0           77.0
# 2         KMDW 2016-06-24 13:53:00            80.1            NaN
# 3         KPNE 2019-05-03 07:54:00            53.0           53.0
# 4         KCVO 2019-04-11 22:56:00            49.0           49.0
#
#    Humidity(%)  Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 0         67.0         29.91            10.0          North              6.9
# 1         96.0         29.94            10.0           CALM              0.0
# 2         43.0         30.06            10.0            ENE             10.4
# 3         86.0         29.99             4.0              E              9.0
# 4         97.0         29.79            10.0            WSW              3.0
#
#    Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  Give_Way  \
# 0                NaN             Clear    False  False     False     False
# 1                0.0            Cloudy    False  False     False     False
# 2                NaN     Partly Cloudy    False  False     False     False
# 3                0.0            Cloudy    False  False      True     False
# 4                0.0            Cloudy    False  False     False     False
#
#    Junction  No_Exit  Railway  Roundabout  Station   Stop  Traffic_Calming  \
# 0     False    False    False       False    False  False            False
# 1      True    False    False       False    False  False            False
# 2     False    False    False       False    False  False            False
# 3     False    False    False       False    False  False            False
# 4     False    False    False       False    False  False            False
#
#    Traffic_Signal  Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False         False          Night          Night
# 1           False         False          Night          Night
# 2            True         False            Day            Day
# 3           False         False            Day            Day
# 4           False         False          Night          Night
#
#   Nautical_Twilight Astronomical_Twilight Day_of_Week  Hour_of_Day  \
# 0               Day                   Day    Thursday           20
# 1             Night                 Night      Monday            0
# 2               Day                   Day      Friday           13
# 3               Day                   Day      Friday            8
# 4             Night                 Night    Thursday           23
#
#    Precipitation_wasnull  Wind_Chill_wasnull  Wind_Speed_wasnull  \
# 0                   True                True               False
# 1                  False               False               False
# 2                   True                True               False
# 3                  False               False               False
# 4                  False               False               False
#
#    Visibility_wasnull  Humidity_wasnull  Temperature_wasnull  \
# 0               False             False                False
# 1               False             False                False
# 2               False             False                False
# 3               False             False                False
# 4               False             False                False
#
#    Pressure_wasnull  Precipitation_filled  Wind_Speed_filled_mean  \
# 0             False                   0.0                     6.9
# 1             False                   0.0                     0.0
# 2             False                   0.0                    10.4
# 3             False                   0.0                     9.0
# 4             False                   0.0                     3.0
#
#    Wind_Speed_filled_median  Humidity_filled_mean  Temperature_filled_mean  \
# 0                       6.9                  67.0                     84.0
# 1                       0.0                  96.0                     77.0
# 2                      10.4                  43.0                     80.1
# 3                       9.0                  86.0                     53.0
# 4                       3.0                  97.0                     49.0
#
#    Temperature_filled_median  Visibility_filled_mean  Pressure_filled_mean  \
# 0                       84.0                    10.0                 29.91
# 1                       77.0                    10.0                 29.94
# 2                       80.1                    10.0                 30.06
# 3                       53.0                     4.0                 29.99
# 4                       49.0                    10.0                 29.79
#
#    Rush_Hour  Wind_Chill_predicted_filled
# 0      False                    85.706876
# 1      False                    77.000000
# 2      False                    79.883464
# 3       True                    53.000000
# 4      False                    49.000000

# %%
# Map of Severity of Accidents in the US
na.plot(kind='scatter', x='Start_Lng', y='Start_Lat', alpha=0.2, label='Severity',
         s=na['Severity'],
            c='Severity', cmap=plt.get_cmap('jet'), colorbar=True, figsize=(12,7))
plt.title('Accidents Map of the US: Feb2016 -Dec2019 (by Severity level)')
plt.legend()
plt.savefig('accidents_map.png')
plt.show();

# %%
# Which side of the road do most accidents occur?
na['Side'].value_counts(normalize=True)
# Out:
# R    0.820823
# L    0.179177
# Name: Side, dtype: float64

# %%
# List by fraction of severity
print(na['Severity'].value_counts(normalize=False).sort_values().to_frame())
print(na['Severity'].value_counts(normalize=True).sort_values().to_frame())
# Out:
#    Severity
# 1       115
# 4     12496
# 3    119180
# 2    268209
#    Severity
# 1  0.000287
# 4  0.031240
# 3  0.297950
# 2  0.670523

# %%
# Day of Week from numbers to name(string)
na['Day_of_Week'] = na['Start_Time'].dt.weekday_name

# %%
#sns.countplot(x='Severity', data=na, title='Count by Severity Value')
all = na.groupby('Day_of_Week')['Severity'].value_counts().unstack(level=1)
all.head(3)
# Out:
# Severity      1      2      3     4
# Day_of_Week
# Friday       23  49112  20776  2011
# Monday       18  47674  18864  1983
# Saturday      6  11349  10191  1368

# %%
# Day of Week from numbers to name(string)
na['Day_of_Week'] = na['Start_Time'].dt.weekday_name

# %%
na.groupby('Day_of_Week')['Severity'].value_counts().unstack(level=1)
# Out:
# Severity      1      2      3     4
# Day_of_Week
# Friday       23  49112  20776  2011
# Monday       18  47674  18864  1983
# Saturday      6  11349  10191  1368
# Sunday       12   9881   8910  1271
# Thursday     19  48924  20325  1899
# Tuesday      19  51158  20115  1981
# Wednesday    18  50111  19999  1983

# %%
all.plot(kind="bar", stacked=True, figsize=(6, 4))
plt.legend(title='Severity')
plt.ylabel("count")
#plt.yticks(np.arange(0, 20, 2.0))
plt.title('Severity Count by Day of Week')
plt.tight_layout()
plt.savefig('severity_count_by_day_of_week.png')
plt.show();

# %%
# subset dataframe with Severity = 4
na_severity_4 = na[na['Severity'] == 4]
Four = na_severity_4.groupby('Day_of_Week')['Severity'].value_counts().unstack(level=1)
Four
# Out:
# Severity        4
# Day_of_Week
# Friday       2011
# Monday       1983
# Saturday     1368
# Sunday       1271
# Thursday     1899
# Tuesday      1981
# Wednesday    1983

# %%
Four.plot(kind="bar", color='crimson',stacked=True, figsize=(8, 4))
plt.title('Most Severe Accidents Count by Day of Week')
plt.savefig('most_severe_accidents_count_by_day_of_week.png')
plt.show();

# %%
# subset dataframe with Severity = 1
# Which days of the week have the least severe accidents

na_severity_1 = na[na['Severity'] == 1]
One = na_severity_1.groupby('Day_of_Week')['Severity'].value_counts().unstack(level=1)
One
# Out:
# Severity      1
# Day_of_Week
# Friday       23
# Monday       18
# Saturday      6
# Sunday       12
# Thursday     19
# Tuesday      19
# Wednesday    18

# %%
One.plot(kind="bar", color='blue',stacked=True, figsize=(8, 4))
plt.title('Least Severe Accidents Count by Day of Week');

# %%
# Are most accidents happening by Day or Night?

na.groupby("Sunrise_Sunset")["Severity"].count().sort_values().plot(kind='bar')
plt.title('Number of Road Accidents by Day & Night');

# %%
# Are the most severe accidents happening by Day or Night?
na_severity_4.groupby("Sunrise_Sunset")["Severity"].count().sort_values().plot(kind='bar', color='crimson')
plt.title('Severity 4 Count by Day & Night');

na_severity_4.groupby("Sunrise_Sunset")["Severity"].value_counts(normalize=False)
# Out:
# Sunrise_Sunset  Severity
# Day             4           7409
# Night           4           5087
# Name: Severity, dtype: int64

# %%
# Number of accidents by Hour of Day
na.groupby("Hour_of_Day")["Severity"].count().sort_values().plot('bar')
plt.title('Number of Accidents by Time_of_Day')
plt.savefig('number_of_accidents_by_time_of_day.png')
plt.show();

# %%
na['Weather_Condition'].nunique()
# Out:
# 97

# %%
# total number of accidents according to Weather conditions
na.groupby('Weather_Condition').Severity.count().sort_values(ascending=False)\
.head(10).plot('bar')
plt.title('Top 10 Weather Conditions Affecting Number of Accidents ')
plt.savefig('top10_weather_conditions_affecting_number_of_accidents.png', bbox='standard',
           bbox_inches='tight', pad_inches=0.4)
plt.show();

# %%
na.groupby('State').Severity.count().sort_values(ascending=False) \
.plot(kind='bar', figsize=(9,5),title="Total number of Accidents by State")
plt.savefig('total_number_of_accidents_by_state.png')
plt.show();

# %%
na.groupby('City').Severity.count().sort_values(ascending=False).head(10).plot(kind='bar', figsize=(8,5),title="Total Number of Accidents by City")
plt.savefig('total_number_of_accidents_by_city.png', bbox='standard', orientation='landscape',
           bbox_inches='tight', pad_inches=0.4)
plt.show();

# %%
# States with the highest count of most severe accidents
four = na[(na['Severity']== 4) & (na['State'])]
#severity_by_state = na.groupby(['Severity', 'State']).Severity.sum().sort_values(ascending=False)

# %%
# Top States with most severe (4) accidents
f = four.groupby('State').Severity.count().sort_values(ascending=False)
f.to_frame()

f.plot(kind='bar', color='crimson', figsize=(9,5),title="Most Severe (level 4) Accidents by State")
plt.savefig('most_severe_accidents_by_state.png')
plt.show();

# %%
# Cities with the highest count of most severe accidents
four_city = na[(na['Severity']== 4) & (na['City'])]

# %%
f_city = four_city.groupby('City').Severity.count().sort_values(ascending=False).head(20)
f_city.to_frame()
# Out:
#                  Severity
# City
# Miami                 223
# Atlanta               190
# Houston               114
# Columbus              106
# Orlando               102
# Chicago               101
# Seattle                93
# Kansas City            84
# Phoenix                82
# Jacksonville           78
# Portland               76
# Los Angeles            72
# Washington             69
# Dallas                 66
# Denver                 66
# Saint Louis            55
# Cincinnati             46
# Detroit                45
# Pittsburgh             44
# Fort Lauderdale        44

# %%
f_city.plot(kind='barh', color='green', title="Top 20 Cities with Most Severe Accidents")
plt.tight_layout()
plt.savefig('top20_cities_with_most_severe_accidents.png', bbox='standard')
plt.show();

# %%
#na[['Start_Time', 'End_Time','Timezone', 'Weather_Timestamp']].head(5)

# %% [markdown]
# ## Pairplots of weather variables:

# %%
p1 = ['Severity', 'Distance(mi)', 'Temperature_filled_mean', 'Wind_Chill_predicted_filled', 'Humidity_filled_mean']
p2 = ['Severity', 'Pressure(in)', 'Visibility(mi)', 'Wind_Speed_filled_median', 'Precipitation_filled']

# %%
sns.pairplot(na, vars=p1, hue='Severity').fig.text(0.33, 1.02,'Pairplot 1', fontsize=20)
#p.fig.text(0.33, 1.02,'Above the plot', fontsize=20)
# Out:
# Text(0.33, 1.02, 'Pairplot 1')

# %%
sns.pairplot(na, vars=p2, hue='Severity').fig.text(0.33, 1.02,'Pairplot 2', fontsize=20)
# Out:
# Text(0.33, 1.02, 'Pairplot 2')

# %% [markdown]
# ## Accidents Trend over Time

# %% [markdown]
# ####  Accident frequency between Feb 2016 - Dec2019 - the complete dataset

# %%
# 1. import relevant datacolumns
annual_accidents = pd.read_csv('US_Accidents_Dec19.csv', usecols=['Severity', 'Start_Time'])

# %%
#2. Convert Start_Time to datetime
annual_accidents['Start_Time'] = pd.to_datetime(annual_accidents['Start_Time'])

# %%
#3. re-sample by Year, and count Number of accidents by Severity:
annual_accidents_unstacked = annual_accidents.resample('Y', on='Start_Time')['Severity'].value_counts()
ann_accidents_16_19 = annual_accidents_unstacked['2016-12-31':'2019-12-31']
ann_accidents_16_19
# Out:
# Start_Time  Severity
# 2016-12-31  2           269847
#             3           126178
#             4            14350
#             1              225
# 2017-12-31  2           461971
#             3           231081
#             4            24149
#             1              282
# 2018-12-31  2           574016
#             3           292570
#             4            25770
#             1              259
# 2019-12-31  2           687573
#             3           237790
#             4            28065
#             1              202
# Name: Severity, dtype: int64

# %%
# 4. Plot Each Severity seperately:
ann_accidents_16_19[:,1].plot(rot=45, marker='v', color='blue')

# Divide Severity 2 and 3 counts by 10, to plot on same graph:
(ann_accidents_16_19[:,2]//10).plot(rot=45, marker='v', color='green')

(ann_accidents_16_19[:,3]//10).plot(rot=45, marker='v', color='orange')
ann_accidents_16_19[:,4].plot(rot=45, marker='v', color='crimson')


# Save figure
plt.legend(['1','2/10', '3/10', '4'])
plt.title('Annual Severity plots for Entire US Accidents Dataset:Feb16-Dec19')
plt.savefig('annual_accident_severity_count_for_entire_dataset.png')

plt.show();

# %%
# following is same as 1. to 4. above but for Resampled 400k dataset:

acc_severity_yearly = na.resample('Y', on='Start_Time')['Severity'].value_counts()
acc_severity_yearly = acc_severity_yearly['2016-12-31':'2019-12-31']
acc_severity_yearly
# Out:
# Start_Time  Severity
# 2016-12-31  2           36109
#             3           16913
#             4            1931
#             1              27
# 2017-12-31  2           62599
#             3           31169
#             4            3253
#             1              35
# 2018-12-31  2           77052
#             3           39140
#             4            3493
#             1              26
# 2019-12-31  2           92449
#             3           31957
#             4            3819
#             1              27
# Name: Severity, dtype: int64

# %%
acc_severity_yearly[:,1].plot(rot=45, marker='v', color='blue')
(acc_severity_yearly[:,2]//10).plot(rot=45, marker='v', color='green')
(acc_severity_yearly[:,3]//10).plot(rot=45, marker='v', color='orange')
acc_severity_yearly[:,4].plot(rot=45, marker='v', color='crimson')
plt.legend(['1','2/10', '3/10', '4'])
plt.title('Annual Accident Count in 400k Dataset')
plt.savefig('annual_accident_count_in400k_dataset.png')

plt.show();

# %%
# Calculating total annual accident count
na.resample('M', on='Start_Time')['Severity'].count().plot(marker='o')
plt.title('Total Monthly Accident Count: Feb2016-Dec19')
plt.savefig('monthly_accident_count_in400k_dataset_Feb16_Dec19')
plt.show();

# %% [markdown]
# ## Effect of Traffic Signals/Junctions/Stops etc. on Accidents

# %%
# Plot counts where accident occurance is 'True' at points of interest:

fig, ax =plt.subplots(1,3)

sns.countplot(na['Traffic_Signal'], ax=ax[0])
sns.countplot(na['Junction'], ax=ax[1])
sns.countplot(na['Crossing'], ax=ax[2])

plt.tight_layout(pad=2.0)
fig.suptitle('Points of Interest with Maximum Accidents', fontsize=12)
plt.savefig('accidents_near_points_of_interest.png')
fig.show();
# Out:
# C:\Users\Toshiba\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
#from pylab import rcParams
#rcParams['figure.figsize'] = 8,5

#sns.set(style="darkgrid")
fig, ax =plt.subplots(1,3)
sns.countplot(na['Give_Way'], ax=ax[0])
sns.countplot(na['Bump'], ax=ax[1])
sns.countplot(na['No_Exit'], ax=ax[2])

plt.tight_layout(pad=1.0)
fig.show()
# Out:
# C:\Users\Toshiba\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
fig, ax =plt.subplots(1,3)

sns.countplot(na['Railway'], ax=ax[0])
sns.countplot(na['Roundabout'], ax=ax[1])
sns.countplot(na['Station'], ax=ax[2])

plt.tight_layout(pad=1.0)
fig.show()
# Out:
# C:\Users\Toshiba\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
fig, ax =plt.subplots(1,4)
sns.countplot(na['Stop'], ax=ax[0])
sns.countplot(na['Traffic_Calming'], ax=ax[1])
sns.countplot(na['Amenity'], ax=ax[2])
sns.countplot(na['Turning_Loop'], ax=ax[3])
plt.tight_layout(pad=0.1)
fig.show()
# Out:
# C:\Users\Toshiba\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
